# %% [markdown]
# # Week 5 - Milestone 1: Smart Tracking System Blockchain Ledger (Submission)

# %% [markdown]
# 1. Open your Python script and load the CSV file from your Homework 1:

# %%
import pandas as pd


# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("data/smart_tracking_data.csv")

# %% [markdown]
# 3. Connect Python to the smart contract.
#  - Ensure Ganache is running in the background.
#  - Establish connection with Web3.py:

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %% [markdown]
# - Load the smart contract:

# %%
# Replace with actual contract address from Remix
contract_address = "0x069af8b9480dcb0001eb618a72d1ff57c3e350de"


# Paste the ABI from Remix
import json

abi_json = '''
[
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataValue",
				"type": "string"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]'''


# Now load it safely as a Python object
abi = json.loads(abi_json)


# Convert to Python-compatible dict
abi = json.loads(abi_json)


# Ensure contract address is in checksum format
contract_address_checksum = web3.to_checksum_address(contract_address)

# Load the smart contract
contract = web3.eth.contract(address=contract_address_checksum, abi=abi)


# Set the default sender address (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x069af8b9480dcb0001eb618a72d1ff57c3e350de

# %% [markdown]
# 4. Send the IoT data to the blockchain. Each row from the CSV file will be stored as a transaction on the blockchain.
#  - Define a function to store IoT data:

# %%
import time


def send_iot_data(device_id, data_type, data_value):
    """Sends IoT data to the deployed smart contract"""
    txn = contract.functions.storeData(device_id, data_type, data_value).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
   
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")

# %% [markdown]
#  - Loop through the CSV file and send each row to the blockchain:

# %%
for _, row in df.iterrows():
    # Example: send temperature as data_type and its value as data_value
    send_iot_data(str(row["device_id"]), str(row["temperature"]), str(row["weight"]))
    time.sleep(1)  # Delay to prevent flooding transactions
# Out:
# ✅ Data Stored: 7.79 - 1.97, Txn Hash: fe64fb163b5e38ccd8ac3b9fddab8a07cee735f187fd9ceaabc609f89b19031a
# ✅ Data Stored: 9.55 - 14.29, Txn Hash: 905bb062554e75a27719504c17925578cbd83b8c2f5f47133c49fd981dad7fb1
# ✅ Data Stored: 4.82 - 15.78, Txn Hash: 0e26445152bd15270091ed6b29ff455e4f7afe3dc00aefc16211fc44cb4fe330
# ✅ Data Stored: 4.81 - 9.33, Txn Hash: c7be5f138ccd828320cfc435583a598a78729f6fab355becb01f1807bca30a3d
# ✅ Data Stored: 5.76 - 16.98, Txn Hash: 36db9ce51dab72a4346e9234a48e3e80cd8a419870516feb937d681096790e50
# ✅ Data Stored: 6.44 - 11.31, Txn Hash: b591295cec4d7a6fa64ff2faeb5c86613bbe1ae6a7a5a093f261d310d51e5e75
# ✅ Data Stored: 4.91 - 3.44, Txn Hash: ab36ee179fd90951bdb456581960082440a48bb6a3462176d4fb3b41fa92d51e
# ✅ Data Stored: 7.22 - 7.25, Txn Hash: 6e1ee3a05443fc356e2eace03f8f5640f48c87f50df1a1e5873a9bfff41d708c
# ✅ Data Stored: 3.32 - 5.68, Txn Hash: 939ac83a239ad99658e45788359ccc8667e6bb37af7c2faf31718f38ee8be18e
# ✅ Data Stored: 3.48 - 23.21, Txn Hash: 369e2c27358921195e5a2410f7312a8178efe038e654577b779ebfa6120b6cf6
# ✅ Data Stored: 4.74 - 22.54, Txn Hash: 70173872c92661a93e2aff5af41ad2737661c07cdb0c2faaa0d5e3a5b0e1f273
# ✅ Data Stored: 3.3 - 1.04, Txn Hash: 8eb22ae51fa2ae939d0228318cc5b0623fffddc01787bf7b600ebbe3bd05eed8
# ✅ Data Stored: 7.84 - 1.16, Txn Hash: ac343dfcb472a789d116541065c8fa1c0aeb1900683c2d921bf3ea1ed432dbe7
# ✅ Data Stored: 8.93 - 13.72, Txn Hash: 2153cee023c14d4c39cfea2b235d90f41787e90a70a5b561a22ba0d61f1fcc91
# ✅ Data Stored: 4.8 - 21.07, Txn Hash: 0ab228d23a584400960e5ccbe221651d21d930bb8bead1a19ffb84462c8e685f
# ✅ Data Stored: 2.62 - 7.57, Txn Hash: 4d9cf51412030111a58441405cc1eb7c2fd33457c8dc1c598cd106e06c9a7ad2
# ✅ Data Stored: 7.6 - 9.54, Txn Hash: 172da4ffbdb13b684966ed5dbbd98584d15ead686581bc15dbe7b38e7e188f2a
# ✅ Data Stored: 3.08 - 11.85, Txn Hash: f32cc4b287832478aa8c5ccc4fb5eb5e725c3b0abeb942328765e559894794da
# ✅ Data Stored: 5.27 - 22.83, Txn Hash: 41e127ae31de064fad0ee701acebbcb99f538ca02788727ff5b8c126d6cf3b90
# ✅ Data Stored: 5.05 - 21.48, Txn Hash: a6d5370bc266eab63c0f2b8d024e69eea51e815776f7304b1cd9500e25bc67bb
# ✅ Data Stored: 2.21 - 3.8, Txn Hash: 41c1e64718030489a316368b33f3a841e6767d8740fdf9d50060b8e8255b0851
# ✅ Data Stored: 5.67 - 4.75, Txn Hash: 36e0390bdd05ae4d3a128819ad39e6a7a373b533b2584b24feb6d40fa9fb7b41
# ✅ Data Stored: 2.55 - 10.24, Txn Hash: 2244cf734939a8ecae545dbddede52f7c0ab96b6b3c6731d25a3a5b98242ad02
# ✅ Data Stored: 3.22 - 19.12, Txn Hash: f6992b4261c9b8fea0c2db76f371560f2711aab54dc4055fe397d7def2cdc964
# ✅ Data Stored: 6.71 - 4.67, Txn Hash: 0a4343925b63094631e45f5c06b9e5fcf70086e509bc7581095192d0bc8b1e29
# ✅ Data Stored: 5.15 - 13.16, Txn Hash: 2fb607a72ab57b531f26484ae4c3436fe75e9fffba96f49fb127fa4bfc0da61b
# ✅ Data Stored: 9.26 - 5.21, Txn Hash: 8eb8edd1d1b44866d9c4d9decc1eb2035ada8ac8d797d74e3d8186227509f617
# ✅ Data Stored: 7.42 - 19.77, Txn Hash: 5c1928fb1d7f1da70515352edabac8e1c5dcd26bf50b44bef32542ca8fb34683
# ✅ Data Stored: 5.89 - 21.88, Txn Hash: 85bbc9a9ba80b50c8e6d07dfee82386528b46a63a4bbc791c6616960fb2950cd
# ✅ Data Stored: 7.95 - 19.27, Txn Hash: e4be77bedbeae77e32a6255d405f5a290774259af06a555eb7a644f32b81e5c3
# ✅ Data Stored: 2.34 - 1.15, Txn Hash: e327967e494be9061d50d48a8c5686bb6344268898a18489ecc191ceb3c21c2c
# ✅ Data Stored: 6.06 - 21.99, Txn Hash: b5d20dba69501857aba613a4abd01116c3e1d2510a20faf9269a064c7b893d81
# ✅ Data Stored: 9.43 - 2.79, Txn Hash: a915017095b47c92578fa431d914abb7639f3efc40e89577d7eb8d7aabb7b097
# ✅ Data Stored: 8.33 - 2.28, Txn Hash: 40b6ca59def076fb734227a34e5120badebd02d7ecd0afc5a312ece2bb600243
# ✅ Data Stored: 7.69 - 11.34, Txn Hash: b990b8be1d0063b32b7aee200d3b94d98d52f4b7bc91c1e495f49a334c4ff471
# ✅ Data Stored: 2.12 - 11.87, Txn Hash: f847b5b70fed71330b8822b1a0d2cdc9c9020ef08f4b3de6efa8fea3de423db6
# ✅ Data Stored: 8.55 - 13.64, Txn Hash: 7000c9a78bb183f3e48983a4242e58b8a222f0b786ecd02f6cf6a7586df575be
# ✅ Data Stored: 5.66 - 6.03, Txn Hash: 7a7604d06371e407dff02b6ba027148b50704c1fbcb840fdffddb23340ed4147
# ✅ Data Stored: 3.67 - 17.82, Txn Hash: 7d6026bbba87a5acc3ee72a1c506ec8f8c017fe23d1e44bbf3625bbde57adea0
# ✅ Data Stored: 2.56 - 8.67, Txn Hash: 0656d7c4c1f96fa78f39f13119bc9bc357d95d1c12722b2edffa514fad99058e
# ✅ Data Stored: 2.81 - 6.96, Txn Hash: c881591039598a1d0bc3d8b7eeb9e85d8ecf31a0d034f6932b38268f601639f1
# ✅ Data Stored: 8.29 - 9.07, Txn Hash: a1ed8364d644806998ef127c22215acd3772342db71680a52f5e59eb8aa5f959
# ✅ Data Stored: 7.27 - 24.09, Txn Hash: 6d25ee853283e841a86d1ef3600bb35b05b1b8be6383d48f6efce4c8f8f24e46
# ✅ Data Stored: 4.47 - 20.28, Txn Hash: ad1fd0f47a7ab397eaef1c5668b24ed0c85b2bbd27bbd7cbbfef936812b9b370
# ✅ Data Stored: 5.86 - 19.48, Txn Hash: 0a6977f6703e1783f494afb21c46c46d7ed8201ef466f6eb7688ee10cd7c0d0d
# ✅ Data Stored: 3.62 - 15.01, Txn Hash: 030cd0f718570e8ff1638f99b8f96cfb7a56adbdf9a0b62d80ffef3b9339ea10
# ✅ Data Stored: 6.74 - 12.8, Txn Hash: 388f5dc2b0a294f2504cc0dbe4c590dada29ad2a39734bff87580118d6b5dd52
# ✅ Data Stored: 7.89 - 6.1, Txn Hash: 4000978204f912330eaf2d66fcc8097d4a0ac44bc4b40c8c97c80be3e9e73bd6
# ✅ Data Stored: 5.57 - 5.42, Txn Hash: 6a2ef7fed7f6c0fa2adf4199508b506608f25755193037ff5a09ad2c35ab838a
# ✅ Data Stored: 9.39 - 13.26, Txn Hash: ad85eb15b70b365ecf96fd1cb0d334894f0d0480f67bdde9afdd12730018692a
# ✅ Data Stored: 5.85 - 11.18, Txn Hash: c0dce67cf0213d95ef5aea2d2869bb4cf353e2a7d3d2f324ca13fc545942049b
# ✅ Data Stored: 3.93 - 14.5, Txn Hash: 65e9efbdb59098fe1a2a17a330d4d6d909c1e59b037dcac8d9033649af0fd3c8
# ✅ Data Stored: 7.55 - 19.09, Txn Hash: c8f980a098b643bbef5dcad15f049d09a534ccec3fe1c92edde10d419979e29c
# ✅ Data Stored: 5.7 - 19.74, Txn Hash: 06e1791ed4a4613bb11c50c912d217926af25abe0e28053d897a94d7defa83cf
# ✅ Data Stored: 3.06 - 17.07, Txn Hash: 81bb4346f6b1b71b80c1599d3d62990c527c921d2f824e45cfca6740af8f4674
# ✅ Data Stored: 2.37 - 8.57, Txn Hash: 694f30c94686660c0f07e80c3266f48908e4309e39cfc28212ac94d6621af115
# ✅ Data Stored: 8.85 - 18.64, Txn Hash: 1e8df2382de63f4c8e72c57356a769c51dd5c5b02545b40e9824adcfbceb85fc
# ✅ Data Stored: 7.55 - 10.78, Txn Hash: d66fcf0e69438f0ed85b4a8adbec3b5a8895515333817b0d0645afe2d6f49461

# %% [markdown]
# 5. Now that the data is on the blockchain, retrieve it to verify storage.
#  - Get total stored records:

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 195

# %% [markdown]
#  - Retrieve and print a specific record

# %%
record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# First Stored Record: [1750311908, 'DVC776', 'temperature', '1.97']
