# %% [markdown]
# # Week 5 - Milestone 1: Smart Tracking System Blockchain Ledger (Submission)

# %% [markdown]
# 1. Open your Python script and load the CSV file from your Homework 1:

# %%
import pandas as pd


# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("smart_tracking_data.csv")

# %% [markdown]
# 3. Connect Python to the smart contract.
#  - Ensure Ganache is running in the background.
#  - Establish connection with Web3.py:

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %% [markdown]
# - Load the smart contract:

# %%
# Replace with actual contract address from Remix
contract_address = "0x6127eb02402608ad211d9f2009ed4d6f84d9814d"


# Paste the ABI from Remix
import json

abi_json = '''
[
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataValue",
				"type": "string"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]
'''


# Now load it safely as a Python object
abi = json.loads(abi_json)


# Convert to Python-compatible dict
abi = json.loads(abi_json)


# Convert contract address to checksum format
checksum_address = web3.to_checksum_address(contract_address)

# Load the smart contract
contract = web3.eth.contract(address=checksum_address, abi=abi)


# Set the default sender address (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x6127eb02402608ad211d9f2009ed4d6f84d9814d

# %% [markdown]
# 4. Send the IoT data to the blockchain. Each row from the CSV file will be stored as a transaction on the blockchain.
#  - Define a function to store IoT data:

# %%
import time


def send_iot_data(device_id, data_type, data_value):
    """Sends IoT data to the deployed smart contract"""
    txn = contract.functions.storeData(device_id, data_type, data_value).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
   
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")

# %% [markdown]
#  - Loop through the CSV file and send each row to the blockchain:

# %%
for _, row in df.iterrows():
    send_iot_data(str(row["device_id"]), "temperature", str(row["temperature"]))
    time.sleep(1)  # Delay to prevent flooding transactions
# Out:
# ✅ Data Stored: temperature - 5.12, Txn Hash: 35bc8008d52ac89e4cb758e89f2ed9f7c7ce0273135bbcd2d7b9ccd17e489c31
# ✅ Data Stored: temperature - 9.51, Txn Hash: b817d120e070d467e4e70614f9128208695dd5127bc189373b42af83ae25c7d8
# ✅ Data Stored: temperature - 5.87, Txn Hash: 334aa8a7557d8275dbcf3bd9fedff444e4448f7a7ce7f6421a2ca3b90534201d
# ✅ Data Stored: temperature - 9.5, Txn Hash: 2e586b7032c6977e0da2b7066286fd827eca7a589c39d25d381893fec4fec6bb
# ✅ Data Stored: temperature - 5.6, Txn Hash: 4fa62f879976dfdfe73c27be48a7e285b198585d51b635f53db7eba898947288
# ✅ Data Stored: temperature - 7.97, Txn Hash: 6f0e9da8d9e67f9831322b324dd4602a22e559428fcb77e559f49bb1e5b4a04d
# ✅ Data Stored: temperature - 7.0, Txn Hash: f4ff79559dfa02db4e73e952ddcbbed79b4aeb25055ca9aabdc072a697712af4
# ✅ Data Stored: temperature - 7.25, Txn Hash: bd5a32388326750777b545f79434b66feee00592080d4c6f601341827e68d4cf
# ✅ Data Stored: temperature - 4.02, Txn Hash: 7f5edded8174dcede0179c6817753ba7c6c1582c93417d0a399f54233feca9bb
# ✅ Data Stored: temperature - 9.88, Txn Hash: c64bdc06c06d72074f9d68d6aa3b16ce348dde352c29385d4ecae3688f403dab
# ✅ Data Stored: temperature - 2.74, Txn Hash: a98f2956c7bee10335f5d4c39b1d8d0db3cfc593b53f829d7ff11f156ada7a61
# ✅ Data Stored: temperature - 5.59, Txn Hash: 1385608a6257a4e6824e370828631be67fc57fe330ef24ccf995673c0700aefd
# ✅ Data Stored: temperature - 7.36, Txn Hash: 3b6735dd4e7335351eb7d11ba3604f5e26d3f86020a2e164080a951f16eb6855
# ✅ Data Stored: temperature - 3.7, Txn Hash: 40e5c05d2a9549824beb8995c38fba653cc4284cb82d588425d08ed17ff47692
# ✅ Data Stored: temperature - 5.8, Txn Hash: 16afddf51b327884ea999b77c2a8d80ae53330709d434dd3199b429bc4da4270
# ✅ Data Stored: temperature - 2.34, Txn Hash: 2448ff324363f8304ec029c5174f92804e3eeb9c41d6d3b1e5153b78ec7442c5
# ✅ Data Stored: temperature - 8.29, Txn Hash: 3335c01ae8b4f88abad1388d844c96ea5b71ace361f42512386ee3231e188394
# ✅ Data Stored: temperature - 6.66, Txn Hash: 0b199bafacfd9dcd95fca0edb680612519441232258cdd611c219f0025874d41
# ✅ Data Stored: temperature - 5.51, Txn Hash: 27ee64c1b3921f7b51cf8ea12ca5933987659e255f1ebb810adad72b5c78e1db
# ✅ Data Stored: temperature - 8.95, Txn Hash: 1c60d243925774448c43214028742e778726f9408dfe71c24ee0279e5007a626
# ✅ Data Stored: temperature - 9.24, Txn Hash: d4eb775c8c4a908c256bb426c67ed436932b6fba6e985d013d4e09e9437a6aeb
# ✅ Data Stored: temperature - 4.93, Txn Hash: 413895e0341c97825f25991d447670154c0ca7c4650badcd79702d43baeb201d
# ✅ Data Stored: temperature - 8.42, Txn Hash: f64fae54042fc3092c17d35592b6d423fccf3a5dd62dda615a64bdd4095da7ba
# ✅ Data Stored: temperature - 4.87, Txn Hash: b311df0b7d111a3200da8c166cbb6d45e489972266673e8d03d465b36bae9b39
# ✅ Data Stored: temperature - 2.02, Txn Hash: 4bf221ec1818b7c94c2b8c07800be58445b52244a47ba1d55c41d54d19e03236
# ✅ Data Stored: temperature - 7.95, Txn Hash: 0607508a812c78eb41d5a241a69598aa8523f107c87e8f681ddc7c4b016833a9
# ✅ Data Stored: temperature - 2.92, Txn Hash: 1ce82fa4e37c9f2d5d74cf452cdf221e40d6d425e259870724f7cc2d33aaec86
# ✅ Data Stored: temperature - 4.91, Txn Hash: 9bb3878c27e63e6dbf06741f3dd0161552df8bf3a4d11d1d88b8271d1cdccc84
# ✅ Data Stored: temperature - 7.91, Txn Hash: 77fe40169b0964e639e23d8e05550c271a1c79b28c74841b83a057e782bb7eeb
# ✅ Data Stored: temperature - 6.98, Txn Hash: bf08d9f9e4bd2e038fc0536e6c34fb7dbd6b77d4b76ed79aa15f498de25a045c
# ✅ Data Stored: temperature - 2.41, Txn Hash: 098dad987091fd173690ef22b328b27ad7b3fe4b2d74f439cd2328a577723cdf
# ✅ Data Stored: temperature - 2.57, Txn Hash: a0c5812d657a4b353de2cbe15c5259ff5a1e88f762c0b65346d67fd3f309fa79
# ✅ Data Stored: temperature - 4.68, Txn Hash: 69763cfec8c11f4ee92c44ba069b82cd612762813fad477e9763ebf5deeacc43
# ✅ Data Stored: temperature - 8.46, Txn Hash: d29336ab1b4d7fc890455a2570942d90bb0e1773fd7a7634a267414f72734377
# ✅ Data Stored: temperature - 9.75, Txn Hash: 548fca49888b2f7215d340bf8b3be100fa22db6c1fd3650e69ee780337e43936
# ✅ Data Stored: temperature - 2.2, Txn Hash: 0c6080fb77c91c9b2fc24f2c124c79e59c6832cd81706dc57b8a405b50f57d70
# ✅ Data Stored: temperature - 4.34, Txn Hash: 3a9b95d541a69a9be8b8c4508d3bf75a6be97f1d6c904281c4d12a9019c275a1
# ✅ Data Stored: temperature - 6.4, Txn Hash: 02fc23b1206fd9b2499395d74d09cf4008f396c1751c20875c4fb9d5dabab81c
# ✅ Data Stored: temperature - 3.14, Txn Hash: fe50d561531121959a63d6ca6c00ec46d4a4ea0e9c3f0425e4e85003f8b78984
# ✅ Data Stored: temperature - 6.23, Txn Hash: 0c675fb34207255069cc7c0b8c3550c7c4b50104c48a39f250df6378e4150db6
# ✅ Data Stored: temperature - 9.8, Txn Hash: 1f90743e2163b749651767301287f13a5bff630511b7bb6dad1e94d1a9d8e1b6
# ✅ Data Stored: temperature - 6.8, Txn Hash: 272d7c70d76b3a9bbfb58dfe8b7fdfeb2d1997a0bb2a439bfc2c921cbd10bc93
# ✅ Data Stored: temperature - 3.72, Txn Hash: bc823e29b3f92967e1e35de4cc90c44c53bb382695aab0dd1db14bcb8eb2d6a2
# ✅ Data Stored: temperature - 2.95, Txn Hash: a7c8b7e6d2e59dd32d0ab48692b3da88538a7c539c77e98e700eac06a542a289
# ✅ Data Stored: temperature - 6.94, Txn Hash: 523660925e64a50f88b3f4ea6b88bd972b046c3e2e23fa4a68e20b93b716de58
# ✅ Data Stored: temperature - 2.27, Txn Hash: 835b51825322b4b2339415b2c8431150bea0a57da070858938318dbe1af8af7f
# ✅ Data Stored: temperature - 5.8, Txn Hash: 87038973c5618544af6d5c5f8b461b3e64adbbecc32d15b7dd1a79af9854a443
# ✅ Data Stored: temperature - 5.36, Txn Hash: 05a40bfb64885adf95a1f9267c177d8ee7e81f485a825a01fbfbd30833ccf892
# ✅ Data Stored: temperature - 7.66, Txn Hash: e0f5f9230d5816b02ac6b6132733aacc8178fbff231a3acfb141d80d40322fd7
# ✅ Data Stored: temperature - 5.27, Txn Hash: 2c4665714eeb25086d519c7e5c0d668be6320e0c63a0f5ca94fdeecf3f2c3cd8
# ✅ Data Stored: temperature - 6.81, Txn Hash: 47d575c110087a465d1002266d2ca822c2415a4b403a70e2182152370aba1958
# ✅ Data Stored: temperature - 9.74, Txn Hash: be744c9b5fb67606b90e6b523170ff0588c5d035dd8a874c0c96ad4a964d3c2e
# ✅ Data Stored: temperature - 7.54, Txn Hash: f81c84e3ae1ca2245a844f17a75b80a98072025d1f4fd4219a64ba67301aebe0
# ✅ Data Stored: temperature - 4.25, Txn Hash: 639c54a358601efcdc9f28aca5f05d3b3aac4cd3186d39a239633696c0e6d6df
# ✅ Data Stored: temperature - 6.41, Txn Hash: 71ecf4a6923ae24a768a99411dc3c41431a6e7c12e274bcaed01bee5fa7b2838
# ✅ Data Stored: temperature - 3.54, Txn Hash: 0c6a9e2f1ee9ca7d8e888e1b7bd9692576c10630c7037cc825b90c735bb01995
# ✅ Data Stored: temperature - 4.56, Txn Hash: 2ee21df4345bdbf09df0ccf476f20698941e2ab6c826b186234af656bead831a
# ✅ Data Stored: temperature - 6.53, Txn Hash: 7c0e9a9333bcc5b7da691737918e9c022d0d7f741073ae26ecd4f1731b68a4cc
# ✅ Data Stored: temperature - 2.82, Txn Hash: 2d36f6c92e5acbe8ca9ab14e765443cd6a3e71377c1ae1ae694943c6879f82ea
# ✅ Data Stored: temperature - 3.02, Txn Hash: 556e8b1e2858be8b6da78e1e1baf501869df6f9b060cfc41e3a9fdf8b59b0b26
# ✅ Data Stored: temperature - 3.16, Txn Hash: da68d92265c6854a8ebebdb8682b9d4ea37d7ba3641fffefd59c100294bc697d
# ✅ Data Stored: temperature - 4.29, Txn Hash: 4a28e59dd222d7c239ee57bdf3d68e10e26bff54bd54f408c8639532974abb88
# ✅ Data Stored: temperature - 2.82, Txn Hash: 8208611d6fd3ace65954b17981cea7f9eec722e7f2738e7dc7e0b21224d0ff6c
# ✅ Data Stored: temperature - 9.47, Txn Hash: 4b62f4dfa0680dd7783f8351dda344b6bfec1aa81e4d1c5db8707667825e352e
# ✅ Data Stored: temperature - 7.07, Txn Hash: 6aabec6ed002a743f3d7a4e3b40c4d5b95fe80a08c02f5a46dd8b7bb4ca69629
# ✅ Data Stored: temperature - 4.6, Txn Hash: 1a811348c949b7c74f56c14cff40611617e4a3f036ffe90f3eebefadf3a662cc
# ✅ Data Stored: temperature - 2.25, Txn Hash: e4b7b2285c63e03f90026283f56fe9830ae0da3d611d1d667baa1110b0650c0c
# ✅ Data Stored: temperature - 5.67, Txn Hash: 5156389de1910bac6e73a0d535b6ccd6ef1b0d8f24386de7a3c65ea5f50f2f2f
# ✅ Data Stored: temperature - 5.45, Txn Hash: 47efdc08afeebdb8d52ea9a9108ed9a284a566e913c813775c4260f77cdb6c9e
# ✅ Data Stored: temperature - 9.25, Txn Hash: 029ad4449e14f9ed7fb081f16d590b6ac101298dc0fce2558f592c19b7cf3641
# ✅ Data Stored: temperature - 8.73, Txn Hash: 251b4309e3799fa4d11bb0ed875a0439f8b67c441997dfce32fe7d0beffafe10
# ✅ Data Stored: temperature - 5.07, Txn Hash: a6c418754c091e324bf1a18bc02d4cc58cb4aa6106d8e2ab911d0e30c9a124e3
# ✅ Data Stored: temperature - 9.32, Txn Hash: 579e58eae5a8d2728ef51fe95c0a5cf23609b17aaec0d80d88c054261bfd446a
# ✅ Data Stored: temperature - 7.26, Txn Hash: 9f395ed94f6a86f87081a6a8dfc2c19c57ac6c95e8174af2600517ca5869473c
# ✅ Data Stored: temperature - 6.41, Txn Hash: bd2f22f28c2e87785959be8a2b5438f74104d22e92fbc0dcc99cbed87c365bf8
# ✅ Data Stored: temperature - 4.35, Txn Hash: 32f0cccd5bf5d4d0a2b602cc34fa11beb13894805d27709c83de4ffa9dcde83c
# ✅ Data Stored: temperature - 8.61, Txn Hash: 50edeb2f51866bd3b9f82fe92f95d1bf06bbecc5ffafcdd4e54b7697adbb1c5a
# ✅ Data Stored: temperature - 8.82, Txn Hash: fb622adfa4a113a14eea7bcd97c38cbc14ca6ed32cf9fefb5f22e262e510a22e
# ✅ Data Stored: temperature - 9.31, Txn Hash: 7b5ebbb018684bb99ea3fa8fa1a5d1316e5838c6ed0bb71f8b3dbe1719ca6acc
# ✅ Data Stored: temperature - 7.94, Txn Hash: 1caedc325b363d8cea86c229916b52fd65a81d6aaa7c0e71e5f5cb566c313851
# ✅ Data Stored: temperature - 5.13, Txn Hash: 316da7d9feff92b6488c81ea55c5a7e4968cdded054ab162536f94e95ae2afa7
# ✅ Data Stored: temperature - 6.47, Txn Hash: 53d06fd416532d5e2bce31d2099df3206eb877c56b09ae19f6679b414d4e15bc
# ✅ Data Stored: temperature - 3.24, Txn Hash: 11e8db555d68a6b5a378d5afb924595df9ad624d099f4ff90cd362d129c6fcc7
# ✅ Data Stored: temperature - 3.34, Txn Hash: 84c41b049908aaf26a470916572524fba28f516c40c108fcb340b7c3efcba3e2
# ✅ Data Stored: temperature - 2.35, Txn Hash: de809dab202901270c93f372a7df11439aa6fbc482bbaf0f09b19cd73d894987
# ✅ Data Stored: temperature - 8.86, Txn Hash: a20ee2509879304bfe33ea50ec97cda153422b3ec6b1659e3616f2e7b8f11675
# ✅ Data Stored: temperature - 7.09, Txn Hash: a99569dce2047b58e45a2aa5da149b161c71cd8829088582e7be1ce8343ba29a
# ✅ Data Stored: temperature - 7.84, Txn Hash: 42875ee89fe64099af62de826686779849b0cba522142203c238871d880af6f0
# ✅ Data Stored: temperature - 9.18, Txn Hash: 2b88802bdf4dd5617d531140878c6e864a183675c4d2b5cee1b10a07b5cb8cbe
# ✅ Data Stored: temperature - 4.94, Txn Hash: 38040b81d7b3653843bd6b6f91ece9dd8a70950d26678e50d681c27d0671c809
# ✅ Data Stored: temperature - 7.15, Txn Hash: a3d8d74f443618255e91dd0119ac074f68d841a6c1bb47bf86a48ed8598bc903
# ✅ Data Stored: temperature - 9.38, Txn Hash: b64d2c90f9c7cc44a7459f020f139afce5a97a5b4075f4f264337165e3387861
# ✅ Data Stored: temperature - 6.9, Txn Hash: d12d35ae79e2abf049c02c263c164433d8ecb96a46d5bf2973e719cacbfff176
# ✅ Data Stored: temperature - 6.22, Txn Hash: e07fd87f96c3bdbd8b726eb11df7542979f8ab55666f70e84ee8a135835c0e3f
# ✅ Data Stored: temperature - 9.51, Txn Hash: a655f11f0ef60c934158bf63aee943053c90174e86ef33a48e07fe19f0bc44ab
# ✅ Data Stored: temperature - 8.87, Txn Hash: ec342fc344c620281265ba0c4d0f3472f1609940bf08d19b70a0b20e5a80b0f5
# ✅ Data Stored: temperature - 7.13, Txn Hash: 9d6e3a16cf1b0cd2dcf7ab25cea6e61121924c7a0ec49d8bce475f03d8019762
# ✅ Data Stored: temperature - 9.89, Txn Hash: 7edfba7b2e01f8d4d1ea46a31b6251c743e3b2f07219bad117d0a2fdb3d70249
# ✅ Data Stored: temperature - 9.82, Txn Hash: ad855e24f89b57bb47090115d3150d02fa6466e0549100a9cb838f9c2d05b07a
# ✅ Data Stored: temperature - 5.93, Txn Hash: 531de331e9774b6b028c5407b88f283e6334e4f9b3231ca37c79cee6ac0e8b5a

# %% [markdown]
# 5. Now that the data is on the blockchain, retrieve it to verify storage.
#  - Get total stored records:

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 103

# %% [markdown]
#  - Retrieve and print a specific record

# %%
record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# First Stored Record: [1750264279, 'TEST001', 'Temperature', '22.5°C']
